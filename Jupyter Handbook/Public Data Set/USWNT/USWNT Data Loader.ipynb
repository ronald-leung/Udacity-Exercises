# %% [markdown]
# This Jupyter notebook provides a utility function for loading the USWNT data into a Dataframe

# %%
#The USWNT data is not as clean as you'd expect. The following util loads them into a data frame for analysis
import uswnt_dataloader as uswnt

# %%
uswnt_df = uswnt.load_uswntData()
uswnt_df.head(200)
# Out:
# Year  2015  columns =  Index(['Player', 'Pos', 'GP', 'GS', 'Min.', 'G', 'A', 'Pts', 'Y/R',
#        'Caps/Goals'],
#       dtype='object')
# Year  2016  columns =  Index(['Player', 'Pos', 'GP', 'GS', 'Min.', 'G', 'A', 'Pts', 'Y/R',
#        'Caps/Goals'],
#       dtype='object')
# Year  2017  columns =  Index(['Player', 'Pos', 'GP', 'GS', 'Min.', 'G', 'A', 'Y/R', 'Caps/Goals'], dtype='object')
# Year  2018  columns =  Index(['Player', 'Pos', 'GP', 'GS', 'Min.', 'G', 'A', 'Y/R', 'Caps/Goals'], dtype='object')
# Year  2019  columns =  Index(['Name', 'Pos.', 'GP', 'GS', 'Min', 'G', 'A', 'Y', 'R', 'Caps', 'Goals'], dtype='object')
#     Year             Name Pos.  GP  GS   Min  G  A  Y    R Caps Goals
# 0   2015    Boxx, Shannon    M   9   2   219  0  1  0    0  195    27
# 1   2015    Brian, Morgan    M  24  19  1663  1  2  1    0   43     4
# 2   2015   Chalupny, Lori    D  11   5   503  2  1  0    0  106    10
# 3   2015    Dunn, Crystal    D   8   6   488  4  3  1    0   20     4
# ...

# %%
uswnt_df.to_csv("uswnt_cleaned.csv")
